# %% [markdown]
# <a href="https://colab.research.google.com/github/hchadha28/tinyLM/blob/main/tinyLM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # tinyLM
# This is a language model.
# Inspired by Andrej Karpathy.

# %%
import torch
